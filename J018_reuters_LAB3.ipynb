# %%
#reuters
from tensorflow.keras.datasets import reuters
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd

# %% [markdown]
# # Load Data

# %%
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# # Preprocess Data

# %%
word_index = reuters.get_word_index()

# Inverting the word index dictionary to decode indices back to words
index_to_word = {index: word for word, index in word_index.items()}

# Decoding function
def decode_review(encoded_review):
    return ' '.join([index_to_word.get(i - 3, '?') for i in encoded_review])

# Decode the train and test data
train_texts = [decode_review(sequence) for sequence in train_data]
test_texts = [decode_review(sequence) for sequence in test_data]

# Create pandas DataFrames
train_df = pd.DataFrame({
    'text': train_texts,
    'label': train_labels
})

test_df = pd.DataFrame({
    'text': test_texts,
    'label': test_labels
})

# Display the first few rows of the train DataFrame
print(train_df.head())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 550378/550378 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#                                                 text  label
# 0  ? ? ? said as a result of its december acquisi...      3
# 1  ? generale de banque sa lt ? br and lt heller ...      4
# 2  ? shr 3 28 dlrs vs 22 cts shr diluted 2 99 dlr...      3
# 3  ? the farmers home administration the u s agri...      4
# 4  ? seton co said its board has received a propo...      4

# %%
train_df
# Out:
#                                                    text  label
# 0     ? ? ? said as a result of its december acquisi...      3
# 1     ? generale de banque sa lt ? br and lt heller ...      4
# 2     ? shr 3 28 dlrs vs 22 cts shr diluted 2 99 dlr...      3
# 3     ? the farmers home administration the u s agri...      4
# 4     ? seton co said its board has received a propo...      4
# ...                                                 ...    ...
# 8977  ? finance minister kiichi miyazawa said japan ...     19
# 8978  ? the price of gold bullion is likely to rise ...     19
# 8979  ? international phoenix energy corp said it la...     25
# 8980  ? shr loss 76 cts vs profit 50 cts net loss 19...      3
# 8981  ? currency fluctuations may ? their influence ...     25
#
# [8982 rows x 2 columns]

# %%
test_df
# Out:
#                                                    text  label
# 0     ? the great atlantic and pacific tea co said i...      3
# 1     ? philippine sugar production in the 1987 88 c...     10
# 2     ? the agriculture department's widening of lou...      1
# 3     ? ? ? oil and gas partnership said it complete...      4
# 4     ? strong south ? winds were keeping many vesse...      4
# ...                                                 ...    ...
# 2241  ? lt toronto sun publishing corp said it plann...      3
# 2242  ? shr loss 45 cts vs profit 20 cts net loss 1 ...      8
# 2243  ? sept 30 shr 44 cts net 905 000 vs 631 000 si...      3
# 2244  ? inland ? inc said is board proposed a two fo...      3
# 2245  ? congress should give the u s agriculture sec...     24
#
# [2246 rows x 2 columns]

# %% [markdown]
# # Generating Embeddings

# %%
import nltk

# Download the WordNet corpus
nltk.download('wordnet')

# If you also plan to use the part of speech tagging, download the 'averaged_perceptron_tagger'
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from gensim.models import FastText
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import remove_stopwords
from nltk.stem import WordNetLemmatizer
import nltk

# Ensure the WordNet corpus is downloaded
nltk.download('wordnet', quiet=True)

# Tokenize the text
def preprocess(text):
    return [
        WordNetLemmatizer().lemmatize(token)
        for token in simple_preprocess(remove_stopwords(text))
    ]

# Preprocess the train and test data
train_df['text'] = train_df['text'].apply(preprocess)
test_df['text'] = test_df['text'].apply(preprocess)

# %%
train_df
# Out:
#                                                    text  label
# 0     [said, result, december, acquisition, space, e...      3
# 1     [generale, banque, sa, lt, br, lt, heller, ove...      4
# 2     [shr, dlrs, v, ct, shr, diluted, dlrs, v, ct, ...      3
# 3     [farmer, home, administration, agriculture, de...      4
# 4     [seton, said, board, received, proposal, chair...      4
# ...                                                 ...    ...
# 8977  [finance, minister, kiichi, miyazawa, said, ja...     19
# 8978  [price, gold, bullion, likely, rise, second, h...     19
# 8979  [international, phoenix, energy, corp, said, l...     25
# 8980  [shr, loss, ct, v, profit, ct, net, loss, v, p...      3
# 8981  [currency, fluctuation, influence, bullion, ma...     25
#
# [8982 rows x 2 columns]

# %%
# tokenize the text
FastText_model = FastText(train_df['text'])
#embedding
def vectorize(text):
    vectors = [FastText_model.wv[word] for word in text if word in FastText_model.wv]
    return np.mean(vectors, axis=0) if vectors else np.zeros(FastText_model.vector_size)

# Vectorize the train and test data
X_train = np.stack(train_df['text'].apply(vectorize))
X_test = np.stack(test_df['text'].apply(vectorize))
X_train.shape
# Out:
# (8982, 100)

# %%
from tensorflow.keras.utils import to_categorical

# One-hot encode the labels
y_train = to_categorical(train_df['label'])
y_test = to_categorical(test_df['label'])
y_train.shape
# Out:
# (8982, 46)

# %% [markdown]
# # Model Training

# %%
#train val split
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
import os
import tensorflow as tf
# Checkpoints -- Saves the best MOdel
model_name = "NN.keras"
checkpoint = ModelCheckpoint(model_name,
                            monitor="val_loss",
                            mode="min",
                            save_best_only = True,
                            verbose=2)
# Defining Tensorflow Model (Edit: Added Dropout Layers to deal with overfitting)
model = Sequential()
model.add(Dense(64, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(46, activation='softmax'))
epochs = 100
# Learning Rate Scheduler -- Change Learning Rate after 70% of epochs
def learning_rate(epoch, lr):
    if epoch < 0.7 * epochs:
        return lr
    else:
        return float(lr * tf.math.exp(-0.009))

lr_scheduler = LearningRateScheduler(learning_rate)
model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=epochs, batch_size=132, validation_data= (X_val, y_val), callbacks = [lr_scheduler,checkpoint ])
# Out:
# Epoch 1/100
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2862 - loss: 3.0857
# Epoch 1: val_loss improved from inf to 1.63952, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3063 - loss: 3.0079 - val_accuracy: 0.6183 - val_loss: 1.6395 - learning_rate: 0.0010
# Epoch 2/100
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6155 - loss: 1.7061
# Epoch 2: val_loss improved from 1.63952 to 1.35092, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6166 - loss: 1.7001 - val_accuracy: 0.6945 - val_loss: 1.3509 - learning_rate: 0.0010
# Epoch 3/100
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6513 - loss: 1.4877
# Epoch 3: val_loss improved from 1.35092 to 1.23341, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6522 - loss: 1.4846 - val_accuracy: 0.7095 - val_loss: 1.2334 - learning_rate: 0.0010
# Epoch 4/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6810 - loss: 1.3575
# Epoch 4: val_loss improved from 1.23341 to 1.17586, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6809 - loss: 1.3575 - val_accuracy: 0.7156 - val_loss: 1.1759 - learning_rate: 0.0010
# Epoch 5/100
# 45/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6864 - loss: 1.3384
# Epoch 5: val_loss improved from 1.17586 to 1.13635, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6868 - loss: 1.3350 - val_accuracy: 0.7223 - val_loss: 1.1364 - learning_rate: 0.0010
# Epoch 6/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7077 - loss: 1.2480
# Epoch 6: val_loss improved from 1.13635 to 1.11296, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7071 - loss: 1.2498 - val_accuracy: 0.7262 - val_loss: 1.1130 - learning_rate: 0.0010
# Epoch 7/100
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6992 - loss: 1.2363
# Epoch 7: val_loss improved from 1.11296 to 1.08410, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6992 - loss: 1.2366 - val_accuracy: 0.7284 - val_loss: 1.0841 - learning_rate: 0.0010
# Epoch 8/100
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7031 - loss: 1.2512
# Epoch 8: val_loss improved from 1.08410 to 1.06546, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7040 - loss: 1.2435 - val_accuracy: 0.7385 - val_loss: 1.0655 - learning_rate: 0.0010
# Epoch 9/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7016 - loss: 1.2426
# Epoch 9: val_loss improved from 1.06546 to 1.05098, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7035 - loss: 1.2288 - val_accuracy: 0.7429 - val_loss: 1.0510 - learning_rate: 0.0010
# Epoch 10/100
# 44/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7221 - loss: 1.1549
# Epoch 10: val_loss improved from 1.05098 to 1.03608, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7210 - loss: 1.1586 - val_accuracy: 0.7474 - val_loss: 1.0361 - learning_rate: 0.0010
# Epoch 11/100
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7161 - loss: 1.1578
# Epoch 11: val_loss improved from 1.03608 to 1.02389, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7162 - loss: 1.1596 - val_accuracy: 0.7507 - val_loss: 1.0239 - learning_rate: 0.0010
# Epoch 12/100
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7350 - loss: 1.1273
# Epoch 12: val_loss improved from 1.02389 to 1.02064, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7331 - loss: 1.1304 - val_accuracy: 0.7540 - val_loss: 1.0206 - learning_rate: 0.0010
# Epoch 13/100
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7289 - loss: 1.1183
# Epoch 13: val_loss improved from 1.02064 to 1.01182, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7279 - loss: 1.1238 - val_accuracy: 0.7529 - val_loss: 1.0118 - learning_rate: 0.0010
# Epoch 14/100
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7346 - loss: 1.1322
# Epoch 14: val_loss improved from 1.01182 to 0.99898, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7328 - loss: 1.1297 - val_accuracy: 0.7579 - val_loss: 0.9990 - learning_rate: 0.0010
# Epoch 15/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7303 - loss: 1.1098
# Epoch 15: val_loss improved from 0.99898 to 0.99027, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7308 - loss: 1.1101 - val_accuracy: 0.7585 - val_loss: 0.9903 - learning_rate: 0.0010
# Epoch 16/100
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7441 - loss: 1.1095
# Epoch 16: val_loss improved from 0.99027 to 0.98326, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7421 - loss: 1.1085 - val_accuracy: 0.7602 - val_loss: 0.9833 - learning_rate: 0.0010
# Epoch 17/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7333 - loss: 1.0959
# Epoch 17: val_loss improved from 0.98326 to 0.97926, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7333 - loss: 1.0960 - val_accuracy: 0.7635 - val_loss: 0.9793 - learning_rate: 0.0010
# Epoch 18/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7295 - loss: 1.0959
# Epoch 18: val_loss improved from 0.97926 to 0.97381, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7310 - loss: 1.0946 - val_accuracy: 0.7613 - val_loss: 0.9738 - learning_rate: 0.0010
# Epoch 19/100
# 44/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7364 - loss: 1.0588
# Epoch 19: val_loss improved from 0.97381 to 0.96661, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7364 - loss: 1.0629 - val_accuracy: 0.7652 - val_loss: 0.9666 - learning_rate: 0.0010
# Epoch 20/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7401 - loss: 1.0642
# Epoch 20: val_loss improved from 0.96661 to 0.96107, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7403 - loss: 1.0653 - val_accuracy: 0.7607 - val_loss: 0.9611 - learning_rate: 0.0010
# Epoch 21/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7433 - loss: 1.0638
# Epoch 21: val_loss improved from 0.96107 to 0.95782, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7436 - loss: 1.0639 - val_accuracy: 0.7663 - val_loss: 0.9578 - learning_rate: 0.0010
# Epoch 22/100
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7501 - loss: 1.0403
# Epoch 22: val_loss improved from 0.95782 to 0.94821, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7491 - loss: 1.0420 - val_accuracy: 0.7685 - val_loss: 0.9482 - learning_rate: 0.0010
# Epoch 23/100
# 45/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7412 - loss: 1.0691
# Epoch 23: val_loss improved from 0.94821 to 0.94494, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7416 - loss: 1.0655 - val_accuracy: 0.7641 - val_loss: 0.9449 - learning_rate: 0.0010
# Epoch 24/100
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7517 - loss: 1.0281
# Epoch 24: val_loss improved from 0.94494 to 0.94131, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7515 - loss: 1.0286 - val_accuracy: 0.7624 - val_loss: 0.9413 - learning_rate: 0.0010
# Epoch 25/100
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7419 - loss: 1.0571
# Epoch 25: val_loss did not improve from 0.94131
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7423 - loss: 1.0543 - val_accuracy: 0.7635 - val_loss: 0.9462 - learning_rate: 0.0010
# Epoch 26/100
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7355 - loss: 1.0618
# Epoch 26: val_loss improved from 0.94131 to 0.93832, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7390 - loss: 1.0549 - val_accuracy: 0.7691 - val_loss: 0.9383 - learning_rate: 0.0010
# Epoch 27/100
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7519 - loss: 1.0390
# Epoch 27: val_loss improved from 0.93832 to 0.92612, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7524 - loss: 1.0367 - val_accuracy: 0.7691 - val_loss: 0.9261 - learning_rate: 0.0010
# Epoch 28/100
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7499 - loss: 1.0342
# Epoch 28: val_loss did not improve from 0.92612
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7490 - loss: 1.0333 - val_accuracy: 0.7718 - val_loss: 0.9267 - learning_rate: 0.0010
# Epoch 29/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7532 - loss: 0.9942
# Epoch 29: val_loss did not improve from 0.92612
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7532 - loss: 0.9948 - val_accuracy: 0.7679 - val_loss: 0.9265 - learning_rate: 0.0010
# Epoch 30/100
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7530 - loss: 1.0019
# Epoch 30: val_loss improved from 0.92612 to 0.91994, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7520 - loss: 1.0070 - val_accuracy: 0.7679 - val_loss: 0.9199 - learning_rate: 0.0010
# Epoch 31/100
# 52/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7381 - loss: 1.0166
# Epoch 31: val_loss improved from 0.91994 to 0.91436, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7387 - loss: 1.0165 - val_accuracy: 0.7713 - val_loss: 0.9144 - learning_rate: 0.0010
# Epoch 32/100
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7551 - loss: 1.0124
# Epoch 32: val_loss improved from 0.91436 to 0.91386, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7536 - loss: 1.0114 - val_accuracy: 0.7752 - val_loss: 0.9139 - learning_rate: 0.0010
# Epoch 33/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7595 - loss: 0.9906
# Epoch 33: val_loss improved from 0.91386 to 0.91192, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7581 - loss: 0.9961 - val_accuracy: 0.7757 - val_loss: 0.9119 - learning_rate: 0.0010
# Epoch 34/100
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7534 - loss: 1.0176
# Epoch 34: val_loss did not improve from 0.91192
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7539 - loss: 1.0166 - val_accuracy: 0.7724 - val_loss: 0.9132 - learning_rate: 0.0010
# Epoch 35/100
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7547 - loss: 1.0144
# Epoch 35: val_loss improved from 0.91192 to 0.91089, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7547 - loss: 1.0142 - val_accuracy: 0.7746 - val_loss: 0.9109 - learning_rate: 0.0010
# Epoch 36/100
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7516 - loss: 0.9999
# Epoch 36: val_loss did not improve from 0.91089
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7513 - loss: 0.9993 - val_accuracy: 0.7735 - val_loss: 0.9117 - learning_rate: 0.0010
# Epoch 37/100
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
# 47/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7789 - loss: 0.9128
# Epoch 83: val_loss did not improve from 0.86272
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7785 - loss: 0.9136 - val_accuracy: 0.7891 - val_loss: 0.8660 - learning_rate: 8.8959e-04
# Epoch 84/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7766 - loss: 0.9095
# Epoch 84: val_loss did not improve from 0.86272
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7765 - loss: 0.9099 - val_accuracy: 0.7902 - val_loss: 0.8629 - learning_rate: 8.8162e-04
# Epoch 85/100
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7649 - loss: 0.9158
# Epoch 85: val_loss did not improve from 0.86272
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7643 - loss: 0.9216 - val_accuracy: 0.7891 - val_loss: 0.8700 - learning_rate: 8.7372e-04
# Epoch 86/100
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7710 - loss: 0.9196
# Epoch 86: val_loss did not improve from 0.86272
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7711 - loss: 0.9160 - val_accuracy: 0.7908 - val_loss: 0.8632 - learning_rate: 8.6589e-04
# Epoch 87/100
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7758 - loss: 0.8862
# Epoch 87: val_loss improved from 0.86272 to 0.86133, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7741 - loss: 0.8958 - val_accuracy: 0.7908 - val_loss: 0.8613 - learning_rate: 8.5813e-04
# Epoch 88/100
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7703 - loss: 0.9399
# Epoch 88: val_loss did not improve from 0.86133
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7705 - loss: 0.9390 - val_accuracy: 0.7908 - val_loss: 0.8655 - learning_rate: 8.5044e-04
# Epoch 89/100
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7697 - loss: 0.9120
# Epoch 89: val_loss did not improve from 0.86133
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7698 - loss: 0.9119 - val_accuracy: 0.7891 - val_loss: 0.8668 - learning_rate: 8.4282e-04
# Epoch 90/100
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7688 - loss: 0.9276
# Epoch 90: val_loss did not improve from 0.86133
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7702 - loss: 0.9244 - val_accuracy: 0.7919 - val_loss: 0.8629 - learning_rate: 8.3527e-04
# Epoch 91/100
# 44/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7737 - loss: 0.9261
# Epoch 91: val_loss did not improve from 0.86133
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7740 - loss: 0.9246 - val_accuracy: 0.7891 - val_loss: 0.8614 - learning_rate: 8.2779e-04
# Epoch 92/100
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7745 - loss: 0.8902
# Epoch 92: val_loss improved from 0.86133 to 0.86011, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7742 - loss: 0.8970 - val_accuracy: 0.7908 - val_loss: 0.8601 - learning_rate: 8.2037e-04
# Epoch 93/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7746 - loss: 0.8978
# Epoch 93: val_loss did not improve from 0.86011
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7743 - loss: 0.9034 - val_accuracy: 0.7919 - val_loss: 0.8633 - learning_rate: 8.1302e-04
# Epoch 94/100
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7748 - loss: 0.8893
# Epoch 94: val_loss did not improve from 0.86011
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7748 - loss: 0.8908 - val_accuracy: 0.7935 - val_loss: 0.8633 - learning_rate: 8.0574e-04
# Epoch 95/100
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7730 - loss: 0.8908
# Epoch 95: val_loss did not improve from 0.86011
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7743 - loss: 0.8945 - val_accuracy: 0.7919 - val_loss: 0.8696 - learning_rate: 7.9852e-04
# Epoch 96/100
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7737 - loss: 0.9008
# Epoch 96: val_loss did not improve from 0.86011
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7725 - loss: 0.9056 - val_accuracy: 0.7913 - val_loss: 0.8625 - learning_rate: 7.9136e-04
# Epoch 97/100
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7615 - loss: 0.9099
# Epoch 97: val_loss did not improve from 0.86011
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7633 - loss: 0.9101 - val_accuracy: 0.7913 - val_loss: 0.8626 - learning_rate: 7.8427e-04
# Epoch 98/100
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7674 - loss: 0.9452
# Epoch 98: val_loss improved from 0.86011 to 0.85876, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7686 - loss: 0.9373 - val_accuracy: 0.7924 - val_loss: 0.8588 - learning_rate: 7.7725e-04
# Epoch 99/100
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7802 - loss: 0.9131
# Epoch 99: val_loss improved from 0.85876 to 0.85792, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7794 - loss: 0.9115 - val_accuracy: 0.7941 - val_loss: 0.8579 - learning_rate: 7.7028e-04
# Epoch 100/100
# 47/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7697 - loss: 0.9285
# Epoch 100: val_loss improved from 0.85792 to 0.85701, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7698 - loss: 0.9262 - val_accuracy: 0.7935 - val_loss: 0.8570 - learning_rate: 7.6338e-04

# %% [markdown]
# # Evaluation

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 5))

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()

# %%
import tensorflow as tf
from sklearn.metrics import accuracy_score, classification_report
# Load the best model
loaded_model = tf.keras.models.load_model(model_name)

# Predict the test data
y_pred = loaded_model.predict(X_test, verbose=0)
y_pred_train = loaded_model.predict(X_train, verbose = 0)
#accuracies
train_acc = accuracy_score([np.argmax(i) for i in y_train],[np.argmax(i) for i in y_pred_train])
test_acc = accuracy_score([np.argmax(i) for i in y_test],[np.argmax(i) for i in y_pred])

# plot
plt.figure(figsize=(14, 5))
plt.bar(['Train', 'Test'], [train_acc, test_acc])
plt.ylabel('Accuracy')
plt.title('Train vs Test Accuracy')
for i, v in enumerate([train_acc, test_acc]):
    plt.text(i, v + 0.01, str(round(v, 2)), ha='center')
plt.show()

# %%
y_test, y_pred = [np.argmax(i) for i in y_test],[np.argmax(i) for i in y_pred]
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.42      0.42        12
#            1       0.54      0.75      0.63       105
#            2       0.78      0.70      0.74        20
#            3       0.91      0.94      0.93       813
#            4       0.80      0.89      0.84       474
#            5       0.00      0.00      0.00         5
#            6       0.30      0.21      0.25        14
#            7       1.00      0.33      0.50         3
#            8       0.64      0.61      0.62        38
#            9       0.58      0.72      0.64        25
#           10       0.50      0.53      0.52        30
#           11       0.63      0.72      0.67        83
#           12       0.62      0.38      0.48        13
#           13       0.55      0.62      0.58        37
#           14       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         9
#           16       0.72      0.81      0.76        99
#           17       0.60      0.25      0.35        12
#           18       0.57      0.40      0.47        20
#           19       0.69      0.74      0.71       133
#           20       0.76      0.46      0.57        70
#           21       0.56      0.74      0.63        27
#           22       0.00      0.00      0.00         7
#           23       0.00      0.00      0.00        12
#           24       0.33      0.05      0.09        19
#           25       0.62      0.74      0.68        31
#           26       0.00      0.00      0.00         8
#           27       0.00      0.00      0.00         4
#           28       0.00      0.00      0.00        10
#           29       1.00      0.25      0.40         4
#           30       0.55      0.50      0.52        12
#           31       0.00      0.00      0.00        13
#           32       0.83      0.50      0.62        10
#           33       1.00      0.60      0.75         5
#           34       0.45      0.71      0.56         7
#           35       0.50      0.17      0.25         6
#           36       0.71      0.45      0.56        11
#           37       0.00      0.00      0.00         2
#           38       0.00      0.00      0.00         3
#           39       0.00      0.00      0.00         5
#           40       0.00      0.00      0.00        10
#           41       0.00      0.00      0.00         8
#           42       0.00      0.00      0.00         3
#           43       0.29      0.33      0.31         6
#           44       1.00      0.80      0.89         5
#           45       0.50      1.00      0.67         1
#
#     accuracy                           0.77      2246
#    macro avg       0.43      0.38      0.38      2246
# weighted avg       0.74      0.77      0.75      2246
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
