# %% [markdown]
# # Classification

# %%
import pandas as pd

# For CSV
data = pd.read_csv('/content/Bike Sales Dashboard.csv')

# %%
data
# Out:
#         ID Martial Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   $40,000         1        Bachelors
# 1    24107        Married    Male   $30,000         3  Partial College
# 2    14177        Married    Male   $80,000         5  Partial College
# 3    24381         Single    Male   $70,000         0        Bachelors
# 4    25597         Single    Male   $30,000         0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   $60,000         2      High School
# 996  28672         Single    Male   $70,000         4  Graduate Degree
# 997  11809        Married    Male   $60,000         2        Bachelors
# 998  19664         Single    Male  $100,000         3        Bachelors
# 999  12121         Single    Male   $60,000         3      High School
#
#          Occupation Home Owner  Cars    Commute Distance         Region  Age  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
import pandas as pd

# Assuming 'data' is your DataFrame and 'Purchased Bike' is the target column
X = data.drop('Purchased Bike', axis=1)
y = data['Purchased Bike']

# Identify categorical and numerical columns
categorical_cols = X.select_dtypes(include=['object']).columns
numerical_cols = X.select_dtypes(exclude=['object']).columns

# Encode categorical target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Preprocessing for numerical data
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Bundle preprocessing for categorical and numerical features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# Apply transformations
X_processed = preprocessor.fit_transform(X)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)

# Model Building
import tensorflow as tf
from tensorflow.keras import layers, models

# Define the model
model = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # For binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy}")
# Out:
# Epoch 1/50
# 25/25 [==============================] - 1s 11ms/step - loss: 0.6935 - accuracy: 0.5475 - val_loss: 0.6744 - val_accuracy: 0.5950
# Epoch 2/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6453 - accuracy: 0.6637 - val_loss: 0.6619 - val_accuracy: 0.6100
# Epoch 3/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6163 - accuracy: 0.6850 - val_loss: 0.6548 - val_accuracy: 0.6000
# Epoch 4/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5921 - accuracy: 0.6975 - val_loss: 0.6474 - val_accuracy: 0.6300
# Epoch 5/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5743 - accuracy: 0.7063 - val_loss: 0.6335 - val_accuracy: 0.6550
# Epoch 6/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5568 - accuracy: 0.7163 - val_loss: 0.6246 - val_accuracy: 0.6650
# Epoch 7/50
# ...
